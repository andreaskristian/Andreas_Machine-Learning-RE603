# %% [markdown]
# # Nama: Andreas Kristian N
# # NIM: 4222301015
# # Kelas: Robotika Pagi A

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Load Our Dataset

# %%
df = pd.read_csv('berat_tinggi.csv')

# %% [markdown]
# ## EDA

# %%
fig, ax = plt.subplots(figsize=(15,10))
sns.scatterplot(data=df, x='berat', y='tinggi')
plt.title('Sebaran Nilai berat vs tinggi')
# Out:
# Text(0.5, 1.0, 'Sebaran Nilai berat vs tinggi')

# %%
df.describe()
# Out:
#             tinggi        berat
# count  8888.000000  8888.000000
# mean    159.125498    71.365302
# std      14.258305    10.729120
# min     134.881305    44.344643
# 25%     148.522565    63.557079
# 50%     153.805704    71.748643
# 75%     170.365514    79.003827
# max     195.232920    98.644868

# %%
# Looping untuk kolom 'berat' dan 'tinggi'
columns = ['berat', 'tinggi']

for col in columns:
    # Box plot
    plt.figure(figsize=(12, 6))
    sns.boxplot(x=col, data=df)
    plt.title(f'Box Plot - {col} Badan (kg)' if col == 'berat' else f'Box Plot - {col} (cm)')
    plt.xlabel(col)
    plt.ylabel('Nilai')
    plt.show()

# %%
for col in columns:
    # Histogram
    plt.figure(figsize=(12, 6))
    sns.histplot(df[col], bins=30, kde=False)
    plt.title(f'Box Plot - {col} Badan (kg)' if col == 'berat' else f'Box Plot - {col} (cm)')
    plt.xlabel(col)
    plt.ylabel('Frekuensi')
    plt.show()

# %% [markdown]
# ## Feature Engineering
# * Unsupervised tidak perlu dilakukan splitting
# 1. Drop Duplikat
# 2. Outlier Handling (opsional)-> pada step ini tidak perlu, karena berat dan tinggi masih wajar untuk nilai seperti itu
# 3. Feature Scalling

# %%
# Drop Duplicates

print(f"Dataframe dimension before duplication drop {df.shape[0]}")

df = df.drop_duplicates().reset_index(drop=True)

print(f"Dataframe dimension after duplication drop {df.shape[0]}")
# Out:
# Dataframe dimension before duplication drop 8888
# Dataframe dimension after duplication drop 8888

# %% [markdown]
# dari hasil running program diatas, tidak ada data yg duplikat

# %%
fitur_columns = ['berat', 'tinggi']
X = df[fitur_columns].values
y = df['deskripsi'].values #anotator label

# %%
# Feature Scalling
from sklearn.preprocessing import StandardScaler
X_std = StandardScaler().fit_transform(X)
df_scalling = pd.DataFrame(data = X_std, columns = fitur_columns )
df_scalling.describe()
# Out:
#               berat        tinggi
# count  8.888000e+03  8.888000e+03
# mean  -9.465376e-16  9.953034e-17
# std    1.000056e+00  1.000056e+00
# min   -2.518583e+00 -1.700451e+00
# 25%   -7.278008e-01 -7.436739e-01
# 50%    3.573103e-02 -3.731224e-01
# 75%    7.119833e-01  7.883579e-01
# max    2.542716e+00  2.532521e+00

# %%
X_std
# Out:
# array([[-1.2118229 , -0.07092171],
#        [-1.75281897,  0.08546572],
#        [-0.87900786,  0.16556767],
#        ...,
#        [-0.89346332, -0.02015625],
#        [-1.6141688 , -0.17762697],
#        [ 1.40264032, -0.3111536 ]], shape=(8888, 2))

# %%
df_scalling
# Out:
#          berat    tinggi
# 0    -1.211823 -0.070922
# 1    -1.752819  0.085466
# 2    -0.879008  0.165568
# 3    -0.216544  1.636598
# 4    -0.002258  1.777105
# ...        ...       ...
# 8883  0.329937  1.274490
# 8884  0.905892 -0.527475
# 8885 -0.893463 -0.020156
# 8886 -1.614169 -0.177627
# 8887  1.402640 -0.311154
#
# [8888 rows x 2 columns]

# %% [markdown]
# ## TO DO!
# - Lengkapi Code dibawah ini, untuk mengecek distribusi sebelum dan setelah dilakukan feature scalling menggunakan standar scaller

# %%
# cek grafik sebelum dan setelah scalling
# kita lihat distribusi dari variabel sebelum standar scaller dan setelah standar scaller

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(14, 5))

# Plot distribusi sebelum Standar Scaler
sns.histplot(df['berat'], ax=ax1, color='blue', kde=True, stat='density', label='berat', alpha=0.6)
sns.histplot(df['tinggi'], ax=ax1, color='orange', kde=True, stat='density', label='tinggi', alpha=0.6)
ax1.set_title('Distribusi sebelum StandardScaler')
ax1.set_xlabel('Nilai asli')
ax1.set_ylabel('Kepadatan')
ax1.legend()

# Plot distribusi setelah Standar Scaler
sns.histplot(df_scalling['berat'], ax=ax2, color='blue', kde=True, stat='density', label='berat', alpha=0.6)
sns.histplot(df_scalling['tinggi'], ax=ax2, color='orange', kde=True, stat='density', label='tinggi', alpha=0.6)
ax2.set_title('Distribusi setelah StandardScaler')
ax2.set_xlabel('Nilai terstandardisasi')
ax2.set_ylabel('Kepadatan')
ax2.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Tulis Interpretasi dari hasil evaluasi diatas :
# 1. Distribusi sebelum dan setelah StandardScaler terlihat bahwa nilai berat dan tinggi telah distandarisasi sehingga berada pada skala yang sama dengan mean 0 dan varian 1.
# 2. Plot sebelum scaling menunjukkan perbedaan skala antara berat dan tinggi, sementara plot setelah scaling memperlihatkan distribusi yang sebanding untuk kedua fitur.
# 3. StandardScaler membantu K-Means agar tidak bias terhadap fitur dengan skala lebih besar.

# %% [markdown]
# ## K-means Clustering
# Pada pembahasan kali ini akan diuji 2 metode pemilihan nilai cluster (K) yang terbaik, mendekati distribusi pada label anotator.
# 1. Metode Elbow
# 2. Via-Score plot

# %% [markdown]
# ### Metode Elbow

# %%
from sklearn.cluster import KMeans
inertia = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, random_state=0)
    kmeans.fit(df_scalling.values)
    inertia.append(kmeans.inertia_)

plt.figure(figsize=(20, 10))
plt.plot(range(1, 11), inertia, color='black', linestyle='--', linewidth=4, marker='o', markersize=10, label='Inertia')
plt.axvline(4, color='green', linestyle='--', linewidth=2, label='Elbow k=4')
plt.scatter(range(1, 11), inertia, s=200, color='#800000')
plt.title('Elbow Method - Finding K value Clusters')
plt.xlabel('The Amount of K')
plt.ylabel('Intertia / WSS')
plt.legend()

# %%
#Dari hasil diatas elbow nya dipilih pada angka 4,
# karena titik awal sebelum titik selanjutnya memiliki gap yang konstan atau
# titik setelah lekukan tajam sebelum mendatar
from sklearn.cluster import KMeans
kmeans_elbow = KMeans(n_clusters=4, random_state=0)
kmeans_elbow.fit(df_scalling.values)
# Out:
# KMeans(n_clusters=4, random_state=0)

# %%
#taruh hasil k-means elbow method ke df dengan nama kolom cluster_elbow
df['cluster_elbow'] = kmeans_elbow.labels_

# %%
df
# Out:
#           tinggi      berat deskripsi  cluster_elbow
# 0     158.114332  58.364240    Normal              0
# 1     160.344026  52.560155    Normal              0
# 2     161.486080  61.934852    Normal              0
# 3     182.459297  69.042108      Slim              2
# 4     184.462584  71.341076      Slim              2
# ...          ...        ...       ...            ...
# 8883  177.296550  74.905033      Slim              2
# 8884  151.605026  81.084183     Obese              3
# 8885  158.838120  61.779766    Normal              0
# 8886  156.592981  54.047666    Normal              0
# 8887  154.689225  86.413551     Obese              3
#
# [8888 rows x 4 columns]

# %%
fig, ax = plt.subplots(figsize=(15,10))
sns.scatterplot(data=df, x='berat', y='tinggi', hue='cluster_elbow')
# Out:
# <Axes: xlabel='berat', ylabel='tinggi'>

# %% [markdown]
# ### Bandingkan hasil dengan label anotator

# %%
fig, ax = plt.subplots(figsize=(15,10))
sns.scatterplot(data=df, x='berat', y='tinggi',hue='deskripsi')
# Out:
# <Axes: xlabel='berat', ylabel='tinggi'>

# %% [markdown]
# ### Hasil diatas ketika menggunakan elbow ialah optimal, karena cluster cocok dengan label anotator yang telah tersedia di deskripsi. Dengan kondisi :
# 1. Cluster 0 -> Normal
# 2. Cluster 1 -> Fat
# 3. Cluster 2 -> Slim
# 4. Cluster 3 -> Obese

# %% [markdown]
# ### 2. Via Score Plot

# %%
from sklearn.metrics import silhouette_score, silhouette_samples

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
import time

# 1. Inisialisasi list untuk menyimpan inertia dan fit time
inertia = []
fit_times = []
k_range = range(1, 11)

# 2. Proses training dan pencatatan waktu
for k in k_range:
    kmeans = KMeans(n_clusters=k, random_state=0)
    
    start_time = time.time()
    kmeans.fit(df_scalling.values)
    end_time = time.time()
    
    inertia.append(kmeans.inertia_)
    fit_times.append(end_time - start_time)

# 3. Setup canvas utama (untuk plot Inertia / Distortion)
fig, ax1 = plt.subplots(figsize=(10, 6))

# Set grid background abu-abu tipis khas Yellowbrick
ax1.grid(True, which='both', linestyle='-', linewidth=0.5, color='lightgray')
ax1.set_facecolor('#f7f7f7')

# Plot garis biru utama (Distortion/Inertia)
sns.lineplot(x=list(k_range), y=inertia, marker='D', color='#1f77b4', linewidth=2, ax=ax1, label='distortion')
ax1.set_xlabel('k', fontsize=11)
ax1.set_ylabel('distortion', fontsize=11)
ax1.set_xticks(k_range)

# 4. Membuat sumbu Y kedua (untuk Fit Time) di sebelah kanan
ax2 = ax1.twinx()
# Plot garis hijau putus-putus (Fit Time)
sns.lineplot(x=list(k_range), y=fit_times, marker='o', color='#98df8a', linestyle='--', linewidth=1.5, ax=ax2, label='fit time')
ax2.set_ylabel('fit time (seconds)', fontsize=11)
ax2.grid(False) # Matikan grid kedua agar tidak tabrakan

# 5. Menambahkan garis putus-putus vertikal hitam pada k=3 (Nilai optimal)
k_optimal = 3
ax1.axvline(x=k_optimal, color='black', linestyle='--', linewidth=1.5, label=f'k = {k_optimal}')

# 6. Menggabungkan Legend dari kedua sumbu
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc='upper right')

# 7. Judul dan Tampilan
plt.title('Distortion Via-Score Plot for K-Means Clustering', fontsize=12, pad=15)
plt.tight_layout()
plt.show()

# %%
df
# Out:
#           tinggi      berat deskripsi  cluster_elbow  cluster_via
# 0     158.114332  58.364240    Normal              0            0
# 1     160.344026  52.560155    Normal              0            0
# 2     161.486080  61.934852    Normal              0            0
# 3     182.459297  69.042108      Slim              2            2
# 4     184.462584  71.341076      Slim              2            2
# ...          ...        ...       ...            ...          ...
# 8883  177.296550  74.905033      Slim              2            2
# 8884  151.605026  81.084183     Obese              3            1
# 8885  158.838120  61.779766    Normal              0            0
# 8886  156.592981  54.047666    Normal              0            0
# 8887  154.689225  86.413551     Obese              3            1
#
# [8888 rows x 5 columns]

# %% [markdown]
# ## Evaluasi Visualisasi K-Means Via Score
# - Berikut adalah evaluasi visualisasi hasil clustering `cluster_via` berdasarkan silhouette score.

# %%
# Lakukan evaluasi setelah dilakukan K-Means
# Bandingkan hasil cluster dengan distribusi data asli
fig, ax = plt.subplots(figsize=(15,10))
sns.scatterplot(data=df, x='berat', y='tinggi', hue='cluster_via', palette='Set1', s=100)
plt.title('Evaluasi K-Means Via Score - Cluster_via')
plt.xlabel('Berat (kg)')
plt.ylabel('Tinggi (cm)')
plt.legend(title='Cluster Via')
plt.show()

# %% [markdown]
# ### Bandingkan dengan label anotator

# %%
fig, ax = plt.subplots(figsize=(15,10))
sns.scatterplot(data=df, x='berat', y='tinggi', hue='deskripsi', palette='Set2', s=100)
plt.title('Distribusi Data Asli berdasarkan Label Anotator')
plt.xlabel('Berat (kg)')
plt.ylabel('Tinggi (cm)')
plt.legend(title='Deskripsi')
plt.show()

# %% [markdown]
# ### Tulis Interpretasi dari hasil evaluasi diatas :
# ### Isi disini
# 1. Hasil evaluasi K-Means via score menunjukkan pembentukan 3 cluster yang cukup jelas, tapi lebih sederhana dibanding label anotator yang memiliki 4 kelas.
# 2. Jika dibandingkan dengan distribusi label anotator, cluster_via cenderung menggabungkan beberapa kelas dan tidak selalu tepat memetakan setiap label ke cluster unik.
# 3. Ini menandakan bahwa pilihan K=3 sesuai untuk pemisahan umum, namun untuk mencocokkan label anotator lebih baik menggunakan K=4 atau analisis cluster tambahan.

# %% [markdown]
# ### Thank you :)
